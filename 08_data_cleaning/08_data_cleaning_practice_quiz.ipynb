# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bsheese/225/blob/main/08_data_cleaning/08_data_cleaning_practice_quiz.ipynb)

# %% [markdown]
# # 08: Data Cleaning Practice Quiz
#
# Run the cell below to launch the interactive quiz.

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..'))
from quiz_engine import QuizApp

quiz_data = [
    {
        'question': '`df.isnull().sum()` returns 0 for the `age` column. What does this mean?',
        'options': [
            'The age column has 0 rows',
            'The age column has no missing values',
            'The age column is not loaded correctly',
            'The age column contains only zero values'
        ],
        'answer': 'The age column has no missing values'
    },
    {
        'question': 'You call `df.dropna()` with no arguments. What is the default behavior?',
        'options': [
            'Drop any column with at least one null',
            'Drop any row with at least one null',
            'Drop only rows where all values are null',
            'Drop only rows where more than 50% of values are null'
        ],
        'answer': 'Drop any row with at least one null'
    },
    {
        'question': '`pd.to_numeric(series, errors="coerce")` -- what does `errors="coerce"` do to non-numeric entries?',
        'options': [
            'Raises a ValueError immediately',
            'Converts them to 0',
            'Converts them to NaN',
            'Leaves them as strings'
        ],
        'answer': 'Converts them to NaN'
    },
    {
        'question': 'A sex column contains "female", "Female", and " female ". After `.str.strip().str.lower()`, how many unique values remain?',
        'options': ['3 (unchanged)', '2', '1', '0 (all become null)'],
        'answer': '1'
    },
    {
        'question': 'What is the main reason to convert `pclass` (values 1, 2, 3) from `int64` to `category` dtype?',
        'options': [
            'It makes arithmetic on the column faster',
            'It signals that the values are labels, not quantities, preventing meaningless averaging',
            'It automatically converts the values to strings',
            'It sorts the values in the correct order automatically'
        ],
        'answer': 'It signals that the values are labels, not quantities, preventing meaningless averaging'
    },
    {
        'question': '`df["name"].str.split(". ", expand=True, n=1)` -- what does `n=1` do?',
        'options': [
            'Keeps only the first element of each split',
            'Limits the split to at most one occurrence, so at most two pieces result',
            'Splits on the first character only',
            'Returns a Series of length 1'
        ],
        'answer': 'Limits the split to at most one occurrence, so at most two pieces result'
    },
    {
        'question': 'The regex pattern `[^\\d]` matches:',
        'options': [
            'Any digit 0-9',
            'Any character that is NOT a digit',
            'The start of a string',
            'Any character that is a digit or a letter'
        ],
        'answer': 'Any character that is NOT a digit'
    },
    {
        'question': 'In `pd.to_datetime(series, format="%m/%d/%Y")`, what does `%m` represent?',
        'options': [
            'Full month name (e.g., "January")',
            'Month as a zero-padded number (01-12)',
            'Minute as a number',
            'Day of the month'
        ],
        'answer': 'Month as a zero-padded number (01-12)'
    },
    {
        'question': 'You subtract two `datetime64` columns. The result has dtype:',
        'options': [
            'int64 (number of days)',
            'float64 (number of seconds)',
            'timedelta64',
            'datetime64'
        ],
        'answer': 'timedelta64'
    },
    {
        'question': 'You have a `timedelta64` column `duration`. How do you convert it to a float column of total seconds?',
        'options': [
            'duration.dt.seconds',
            'duration.dt.total_seconds()',
            'duration.astype(float)',
            'pd.to_numeric(duration)'
        ],
        'answer': 'duration.dt.total_seconds()'
    },
    {
        'question': 'Which `.str` method returns a boolean Series indicating whether each element contains a given substring?',
        'options': [
            '.str.equals()',
            '.str.contains()',
            '.str.match()',
            '.str.find()'
        ],
        'answer': '.str.contains()'
    },
    {
        'question': 'In a cleaning pipeline, why is renaming columns usually the first step?',
        'options': [
            'pandas requires renamed columns before any other operations',
            'It makes all subsequent code readable and avoids escaping special characters in column names',
            'It automatically drops columns with missing values',
            'It converts column dtypes to the correct types'
        ],
        'answer': 'It makes all subsequent code readable and avoids escaping special characters in column names'
    }
]

app = QuizApp(quiz_data, 'Data Cleaning Quiz')
app.run()
