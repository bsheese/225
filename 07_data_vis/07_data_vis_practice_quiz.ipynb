# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bsheese/225/blob/main/07_data_vis/07_data_vis_practice_quiz.ipynb)

# %% [markdown]
# # 07: Data Visualization Practice Quiz
#
# Run the cell below to launch the interactive quiz.

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..'))
from quiz_engine import QuizApp

quiz_data = [
    {
        'question': '`sns.histplot()` returns a ____; `sns.displot()` returns a ____.',
        'options': ['Axes; FacetGrid', 'FacetGrid; Axes', 'Figure; Axes', 'Axes; Figure'],
        'answer': 'Axes; FacetGrid'
    },
    {
        'question': 'What does `sns.set_theme(style="whitegrid", context="notebook")` control?',
        'options': [
            'The data loaded into the chart and the number of bins',
            'The background/grid appearance and the scale of text and lines',
            'The color palette and the chart type',
            'The figure size and the x-axis range'
        ],
        'answer': 'The background/grid appearance and the scale of text and lines'
    },
    {
        'question': 'A distribution with a long tail extending to the right and a mean above the median is called ____.',
        'options': ['left-skewed', 'symmetric', 'right-skewed', 'bimodal'],
        'answer': 'right-skewed'
    },
    {
        'question': '`sns.histplot(data=df, x="age", hue="survived", common_norm=False)` -- what does `common_norm=False` do?',
        'options': [
            'Normalizes all hue groups together so their areas sum to 1',
            "Normalizes each hue group independently so each group's area sums to 1",
            'Disables normalization so the y-axis shows raw counts',
            'Removes the color distinction between hue groups'
        ],
        'answer': "Normalizes each hue group independently so each group's area sums to 1"
    },
    {
        'question': 'You want to show the mean survival rate for each passenger class as bars with confidence intervals. Which function is most direct?',
        'options': ['sns.countplot()', 'sns.barplot()', 'sns.histplot()', 'sns.scatterplot()'],
        'answer': 'sns.barplot()'
    },
    {
        'question': '`sns.regplot()` adds a line to a scatter plot. What does that line represent?',
        'options': [
            'A smoothed KDE of the data',
            'A linear regression fit',
            'The rolling mean of y',
            'The median of y within each x bin'
        ],
        'answer': 'A linear regression fit'
    },
    {
        'question': 'You have a scatter plot of age vs fare and want to encode sex as color. Which argument does this?',
        'options': ['col="sex"', 'hue="sex"', 'style="sex"', 'palette="sex"'],
        'answer': 'hue="sex"'
    },
    {
        'question': '`sns.displot(data=df, x="age", col="pclass")` for a dataset with three classes creates how many panels?',
        'options': ['1', '2', '3', 'It depends on col_wrap'],
        'answer': '3'
    },
    {
        'question': 'A Pearson correlation of -0.55 between pclass and fare means:',
        'options': [
            'Higher class number (lower cabin class) is associated with lower fare',
            'Higher class number is associated with higher fare',
            'Class and fare are unrelated',
            'Fare determines class assignment'
        ],
        'answer': 'Higher class number (lower cabin class) is associated with lower fare'
    },
    {
        'question': 'Which colormap type is most appropriate for a heatmap showing correlations ranging from -1 to +1?',
        'options': [
            'Qualitative (e.g., "Set2")',
            'Sequential (e.g., "viridis")',
            'Diverging (e.g., "vlag")',
            'Any colormap works equally well'
        ],
        'answer': 'Diverging (e.g., "vlag")'
    },
    {
        'question': 'After drawing an axes-level chart `ax = sns.histplot(...)`, how do you add a title?',
        'options': [
            'plt.title("My title")',
            'ax.set_title("My title")',
            'sns.set_title("My title")',
            'g.figure.suptitle("My title")'
        ],
        'answer': 'ax.set_title("My title")'
    },
    {
        'question': 'You want to save a figure-level chart to PNG at 150 dpi. The chart is stored in `g`. Which call is correct?',
        'options': [
            'plt.savefig("chart.png", dpi=150, bbox_inches="tight")',
            'g.savefig("chart.png", dpi=150, bbox_inches="tight")',
            'ax.savefig("chart.png", dpi=150)',
            'sns.savefig(g, "chart.png")'
        ],
        'answer': 'g.savefig("chart.png", dpi=150, bbox_inches="tight")'
    }
]

app = QuizApp(quiz_data, 'Data Visualization Quiz')
app.run()
